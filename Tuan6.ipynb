# %% [markdown]
# W5A1 Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two( a, b) ->
# int:

# %%
x,y = map(int,input().split())
a = max(x,y)
print(a)
# Out:
# 3

# %% [markdown]
# W5A2 Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
from typing import Tuple
a,b = map(int,input().split("/"))
def swap(a:int,b:int) -> Tuple[int, int]:

    a = a ^ b 
    b = a ^ b
    a = a ^ b
    return a,b
print(swap(a,b))
# Out:
# (47576, 34567)

# %% [markdown]
# W5A3 Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
a - int(input())
def prime(a):
    if a < 2:
        return False


    i = 2
    while i * i <= a:
        if a % i == 0:
            return False
        i += 1
    return True

print(prime(a))
# Out:
# False

# %% [markdown]
# W5A4 VIết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên

# %%
n = int(input())
def perfect_num(n):  
    if  n < 2:
        return False
    
    s = 1 
    i = 2 

    while  i * i <= n:
        if n % i == 0:
           s += i 
           if i != n // i:
               s+= n // i
        i += 1

    return s == n

print(perfect_num(n))
# Out:
# True

# %% [markdown]
# W5A5 Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử
# đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
n = list(map(int,input().split("/")))
k = int(input())
def find_first_position(n, k):
    for i in range(len(n)):
        if n[i]== k :
            return i
    return -1 
print(find_first_position(n, k))
# Out:
# 2

# %% [markdown]
# W5A6 Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
n = int(input())
def giai_thua(n):
    result = 1
    for i in range(1,n+1):
        result *= i
    return result
print(giai_thua(n))
# Out:
# 720

# %% [markdown]
# W5A7
# Viết hàm giả lập một máy tính bỏ túi.
# Hàm thực hiện tính toán kết quả của phép toán giữa số \( num1 \) và \( num2 \) với toán tử \( operat
# \)
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ \( - \)
# Phép cộng \( + \)
# Phép chia \( / \)
# Phép nhân \( * \)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán \(+, -, *, /\)).
# Đầu ra: Kết quả phép toán.

# %%
a,b=map(int,input().split("/"))
operator=input()
def calculator(a,b,operat):
    if operator == "+":
        return a + b
    elif operator == "-":
        return a - b
    if operator == "x":
        return a * b
    elif operator == ":":
        if b == 0:
            return "Math Error!"
        else:
            return a / b
    else:
        return "Mày nhập cl j đây =)))"
print(calculator(a, b, operator))
# Out:
# Mày nhập cl j đây =)))

# %% [markdown]
# W5A8
# Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dãy bits tương ứng
# của chúng. Ví dụ: Khoảng cách Hamming giữa 1 (1) và 4 (100) là 2.
# Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
# Khoảng cách Hamming là cái tên được đặt theo tên của Richard Hamming, người giới thiệu lý
# thuyết này trong tài liệu có tính cơ sở của ông về mã phát hiện lỗi và sửa lỗi (error-detecting and
# error-correcting codes). Nó được sử dụng trong kỹ thuật viễn thông để tính số lượng các bit trong
# một từ nhị phân (binary word) bị đổi ngược, như một hình thức để ước tính số lỗi xảy ra trong quá
# trình truyền thông, và vì thế, đôi khi, nó còn được gọi là khoảng cách tín hiệu (signal distance). Việc
# phân tích trọng số Hamming của các bit còn được sử dụng trong một số ngành, bao gồm lý thuyết
# tin học, lý thuyết mã hóa, và mật mã học. Tuy vậy, khi so sánh các dãy ký tự có chiều dài khác
# nhau, hay các dãy ký tự có xu hướng không chỉ bị thay thế không thôi, mà còn bị ảnh hưởng bởi dữ
# liệu bị lồng thêm vào, hoặc bị xóa đi, phương pháp đo lường phức tạp hơn, như khoảng cách
# Levenshtein (Levenshtein distance) là một phương pháp có tác dụng và thích hợp hơn.

# %%
s1,s2 = map(str,input().split("/"))
def hamming_distance(s1,s2):
    if len(s1)!=len(s2):
        raise ValueError("2 chuỗi ký tự không cùng độ dài")
     
    dem = 0
    for i in range(len(s1)):
        if s1[i] != s2[i]:
            dem += 1
    return dem

print(hamming_distance(s1,s2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 12
#       9             dem += 1
#      10     return dem
# ---> 12 print(hamming_distance(s1,s2))
#
# Cell In[19], line 4, in hamming_distance(s1, s2)
#       2 def hamming_distance(s1,s2):
#       3     if len(s1)!=len(s2):
# ----> 4         raise ValueError("2 chuỗi ký tự không cùng độ dài")
#       6     dem = 0
#       7     for i in range(len(s1)):
#
# ValueError: 2 chuỗi ký tự không cùng độ dài

# %% [markdown]
# W5A9 Viết hàm trả về tổng các chữ số của số nguyên dương n

# %%
a = int(input())
def tong(a):
    tong = 0
    for i in range(1,a+1):
        tong += i
    return tong
print(tong(a))
# Out:
# 28

# %% [markdown]
# W5A11 Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a*b chia hết cho 10, ngược lại False

# %%
a,b = map(int,input().split("/"))
def is_product_divisible_by_10(a, b):
    if a*b % 10 == 0:
        return True
    else:
        return False
    
print(is_product_divisible_by_10(a,b))
# Out:
# False

# %% [markdown]
# W5A12 Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và
# 0 <= |r| < |divisor|.

# %%
dividend,divisor=map(int,input().split("/"))
def divide_with_remainder(dividend, divisor):
    q = dividend // divisor
    r = dividend % divisor
    return q,r
print(divide_with_remainder(dividend,divisor))
# Out:
# (2, 3)

# %% [markdown]
# W5A13 Viết hàm max_of_two(a, b) trả về số lớn hơn trong hai số.

# %%
a,b = map(int,(input().split("/")))
def max(a,b):
    if a > b:
        return a
    return b
print(max(a,b))
# Out:
# 6

# %% [markdown]
# W5A14 Viết hàm compute(a, b, op) thực hiện phép tính a (+|-|*|/) b tùy theo ký tự op.

# %%
def compute(a, b, op):
    if op == '+':
        return a + b
    elif op == '-':
        return a - b
    elif op == '*':
        return a * b
    elif op == '/':
        if b == 0:
            return "Không thể chia cho 0"
        return a / b
    else:
        return "Toán tử không hợp lệ"

# %% [markdown]
# W5A15 Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông.

# %%
a,b,c = map(int,input().split("/"))
def right_triangle(a, b, c):
    if a > 0 and b > 0 and c > 0 and a + b > c and a + c > b and b + c > a:
        if a ** 2 + b ** 2 == c ** 2 or a ** 2 == b**2 + c**2 or b **2 == a**2 + c**2:
            return True
        else:
            return False
    else:
        return False
print(right_triangle(a,b,c))
# Out:
# True

# %%
def compare_bmi(bmi1,bmi2) -> int:
    if(bmi1 > bmi2):
        return 1
    if(bmi2 > bmi1):
        return 2
    else:
        return 0
    
assert compare_bmi(26,26) == 0
assert compare_bmi(1,10) == 2
print("Pass all test")
# Out:
# Pass all test

# %%
def map_grade(s):
    if s >= 9:
        return "A+"
    elif s >= 8.5:
        return "A"
    elif s >= 8:
        return "B+"
    elif s >= 7:
        return "B"
    elif s >= 6.5:
        return "C+"
    elif s >= 5.5:
        return "C"
    elif s >= 5:
        return "D+"
    elif s>= 4:
        return "D"
    else:
        return "F"
assert map_grade(3.2)== "F"
assert map_grade(5.3)== "D+"
print("Pass")
# Out:
# Pass

# %%
def piecewise_mod3(n):
    if n % 3 == 1:
        return 5*n + 1
    elif n % 3 == 2:
        return 6*n + 2 
    elif n % 3 == 0:
        return 7*n + 3 
assert piecewise_mod3(21)==21
print("Pass!")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 8
#       6     elif n % 3 == 0:
#       7         return 7*n + 3
# ----> 8 assert piecewise_mod3(21)==21
#       9 print("Pass!")
#
# AssertionError:
